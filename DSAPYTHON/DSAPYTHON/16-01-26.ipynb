# %%
age = int(input())

if age >= 18:
    print("Eligible to Vote")
else:
    print("Not Eligible")
# Out:
#  19
# Eligible to Vote

# %%
n = int(input())

if n % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
#  5
# Odd

# %%
n = int(input())
print(n % 10)
# Out:
#  12
# 2
