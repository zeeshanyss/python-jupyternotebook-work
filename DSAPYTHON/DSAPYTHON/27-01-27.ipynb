# %%
def sumOfNumbers(a,b,c):
    s = a + b + c
    return(s)

ans = sumOfNumbers(1,2,3)
print(ans)
# Out:
# 6

# %%
def scope():
# LOCAL VARIABLE 
    b = 10
    print(b)
    return
# GLOBAL VARIABLE
a = 20
scope()
print(a)
print(b)
# Out:
# 10
# 20
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 10
#       8 scope()
#       9 print(a)
# ---> 10 print(b)
#
# NameError: name 'b' is not defined

# %%
    def fun(a, b = 20): # only right most element declare
        return a+b

fun(10)
fun(10,50)
# Out:
# 60

# %%
import math

print(math.pow(2,3))
# Out:
# 8.0

# %%
# USING ELSE IN LOOP: 
# else only will be executed when
for i in range(5):
    print(i)

else:
    print("This else is executed.")
# Out:
# 0
# 1
# 2
# 3
# 4
# This else is executed.

# %%
"apple"
type(23.2)
# Out:
# float

# %%
#CONCATENATION




var = "sweet" +   "apple"
list(var.strip())

# INDEXING STRING

s = "abcdef"
print(s[0])
print(len(s))
print(s[-1])
print(s[2:5])
print(s.append())
# Out:
# a
# 6
# f
# cde
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 16
#      14 print(s[-1])
#      15 print(s[2:5])
# ---> 16 print(s.append())
#
# AttributeError: 'str' object has no attribute 'append'
